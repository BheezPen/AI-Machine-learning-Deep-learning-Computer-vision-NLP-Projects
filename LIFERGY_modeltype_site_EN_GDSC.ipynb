# %% [markdown]
# <a href="https://colab.research.google.com/github/BheezPen/AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects/blob/main/LIFERGY_modeltype_site_EN_GDSC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary liraries to handle my data.
import pandas as pd
import numpy as np

# %%
import pandas as pd

# Specify the shareable link to your dataset
dataset_link = "https://drive.google.com/file/d/1UrznmTdDGNlx-rJ_gj3ndsjddTn-fjEk/view?usp=sharing"

# Extract the file ID from the link
file_id = dataset_link.split("/")[-2]

# Construct the download link
download_link = f"https://drive.google.com/uc?id={file_id}"

# Read the dataset into a Pandas DataFrame
data_df = pd.read_csv(download_link)
# Out:
# <ipython-input-8-61467ea0a1d4>:13: DtypeWarning: Columns (6,7,8,11,12,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(download_link)

# %%
# load the dataset locally
#data_path = 'Datasets\EAJ0001C\0_EAJ0001C_log_20230828-1605_to_20231027-1605'

# %%
# Display the shape of the DataFrame
data_df.shape
# Out:
# (90186, 113)

# %%
data_df.info

# %%
from IPython.display import display

#pd.set_option('display.max_columns', None)

display(data_df.head(50))
# Out:
#    <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.-EdtPCIkpg4.L.X.O/am=HwgrInNsAMr_B0ABAAGAAgUAAAAAAAAAQKCBWEI/d=1/ed=1/rs=AOaEmlFhjjOZXAFySTk3D5Kskz8cCrzBHg/m=identifierview  \
# 0                                            --c-afwt
# 1     );letter-spacing:0rem;line-height:1.42857143...
# 2                                            --c-brsz
# 3     )}.bEbGY{-webkit-box-pack:center;-webkit-jus...
# 4                                            --c-brsz
# 5     )}.no7ij{display:-webkit-box;display:-webkit...
# 6                                            --c-brsz
# 7                             );width:48px;width:var(
# 8                                            --c-brsz
# 9     )}.FZfKCe{display:-webkit-box;display:-webki...
# 10                                           --c-gutw
# ...

# %%
pd.set_option('display.max_rows', None)
null_values = data_df.isnull().sum()

print("Columns with Null Values:")
print(null_values)
# Out:
# Columns with Null Values:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
